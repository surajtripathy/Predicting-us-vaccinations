# %% [markdown]
# ### Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Fall2021/519_project
# Out:
# /content/drive/MyDrive/Fall2021/519_project

# %% [markdown]
# ### Import libraries/data

# %%
import pandas as pd
import seaborn as sns

# %%
ageDf = pd.read_csv( 'ageTrends.csv' )

# %%
demographicsDf = pd.read_csv( 'demographicsTrends.csv' )

# %%
ageDf
# Out:
#         Date Administered  ... Series_Complete_Pop_pct_agegroup
# 0     2021-10-15T00:00:00  ...                            0.003
# 1     2021-10-15T00:00:00  ...                            0.457
# 2     2021-10-15T00:00:00  ...                            0.533
# 3     2021-10-15T00:00:00  ...                            0.538
# 4     2021-10-15T00:00:00  ...                            0.580
# ...                   ...  ...                              ...
# 2749  2020-12-14T00:00:00  ...                              NaN
# 2750  2020-12-14T00:00:00  ...                              NaN
# 2751  2020-12-14T00:00:00  ...                              NaN
# 2752  2020-12-14T00:00:00  ...                              NaN
# 2753  2020-12-14T00:00:00  ...                              NaN
#
# [2754 rows x 5 columns]

# %%
demographicsDf
# Out:
#             Date  ... Series_Complete_Pop_Pct_US
# 0     10/19/2021  ...                        0.0
# 1     10/19/2021  ...                        0.0
# 2     10/19/2021  ...                        0.0
# 3     10/19/2021  ...                        0.0
# 4     10/19/2021  ...                        0.0
# ...          ...  ...                        ...
# 8631  12/14/2020  ...                        0.0
# 8632  12/13/2020  ...                        0.0
# 8633  12/13/2020  ...                        0.0
# 8634  12/13/2020  ...                        0.0
# 8635  12/13/2020  ...                        0.0
#
# [8636 rows x 10 columns]

# %% [markdown]
# ### Exploration

# %%
ageDf[ 'AgeGroupVacc' ].unique()
# Out:
# array(['<12 Years', '12 - 15 Years', '16 - 17 Years', '18 - 24 Years',
#        '25 - 39 Years', '40 - 49 Years', '50 - 64 Years', '65 - 74 Years',
#        '75+ Years'], dtype=object)

# %%
sns.lineplot( data=ageDf.iloc[::-1], x="Date Administered", y="Administered_Dose1_pct_agegroup", hue='AgeGroupVacc' )

# %%
sns.lineplot( data=ageDf.iloc[::-1], x="Date Administered", y="Series_Complete_Pop_pct_agegroup", hue='AgeGroupVacc' )

# %%
sns.lineplot( data=ageDf.iloc[::-1], x="Date Administered", y="7-day_avg_group_cases_per_100k", hue='AgeGroupVacc' )

# %%
demographicsDf.head( 58 )
# Out:
#           Date  ... Series_Complete_Pop_Pct_US
# 0   10/19/2021  ...                        0.0
# 1   10/19/2021  ...                        0.0
# 2   10/19/2021  ...                        0.0
# 3   10/19/2021  ...                        0.0
# 4   10/19/2021  ...                        0.0
# 5   10/19/2021  ...                        0.0
# 6   10/19/2021  ...                        0.0
# 7   10/19/2021  ...                        0.0
# 8   10/19/2021  ...                        0.0
# 9   10/19/2021  ...                        0.0
# 10  10/19/2021  ...                        0.0
# 11  10/19/2021  ...                        0.0
# 12  10/19/2021  ...                       99.0
# 13  10/19/2021  ...                        0.0
# 14  10/19/2021  ...                       99.2
# 15  10/19/2021  ...                        0.0
# 16  10/19/2021  ...                        0.0
# 17  10/19/2021  ...                        0.0
# 18  10/19/2021  ...                        0.0
# ...
